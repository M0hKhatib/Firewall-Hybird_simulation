# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import time
import ipaddress
import datetime
import logging
from collections import Counter
import random
from tqdm import tqdm


logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("firewall_simulation.log"),
        logging.StreamHandler()
    ]
)

class NetworkFirewall:
    def __init__(self):
        self.common_ports = {
            20: "FTP Data", 21: "FTP Control", 22: "SSH", 23: "Telnet",
            25: "SMTP", 53: "DNS", 80: "HTTP", 443: "HTTPS",
            3306: "MySQL", 3389: "RDP", 445: "SMB", 1433: "SQL Server",
            8080: "HTTP Alt", 8443: "HTTPS Alt", 5900: "VNC"
        }

        self.blocked_count = 0
        self.allowed_count = 0
        self.suspicious_count = 0
        self.total_packets = 0

        self.blocked_ips = [
            "185.174.102.56", "91.213.8.43", "185.180.12.15",
            "103.43.141.122", "45.95.147.23", "198.12.64.10",
            "5.255.96.50", "185.159.128.78", "194.36.189.51"
        ]

        self.internal_network = ipaddress.IPv4Network("192.168.1.0/24")
        self.dmz_network = ipaddress.IPv4Network("172.16.1.0/24")
        self.sensitive_servers = ["192.168.1.10", "192.168.1.20", "172.16.1.5"]


        self.anomaly_model = None
        self.scaler = StandardScaler()
        self.connection_history = {}
        self.ip_connection_counts = Counter()


        self.alerts = []
        self.suspicious_connections = set()


        self.traffic_logs = []


        self._initialize_anomaly_model()

        logging.info("Network Firewall initialized successfully")

    def _initialize_anomaly_model(self):

        normal_data = self._generate_synthetic_training_data(5000)


        X_scaled = self.scaler.fit_transform(normal_data)


        self.anomaly_model = IsolationForest(
            n_estimators=100,
            max_samples='auto',
            contamination=0.01,
            random_state=42
        )
        self.anomaly_model.fit(X_scaled)

        logging.info("Anomaly detection model initialized and trained")

    def _generate_synthetic_training_data(self, n_samples):

        data = np.zeros((n_samples, 5))

        data[:, 0] = np.random.normal(500, 200, n_samples)


        data[:, 1] = np.random.normal(50, 20, n_samples)


        data[:, 2] = np.random.exponential(60, n_samples)


        data[:, 3] = np.random.normal(2, 0.5, n_samples)


        data[:, 4] = np.random.uniform(0, 24, n_samples) / 24.0

        return data

    def _step1_data_input(self, packet):

        self.total_packets += 1


        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")
        logging.debug(f"[STEP 1] Processing packet: {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']} ({packet['size']} bytes)")


        packet['timestamp'] = timestamp
        packet['packet_id'] = self.total_packets
        self.traffic_logs.append(packet)

        return packet

    def _step2_rule_inspection(self, packet):

        if packet['src_ip'] in self.blocked_ips:
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = "Source IP in blocklist"
            logging.info(f"[STEP 2] BLOCKED packet from {packet['src_ip']} - Source IP in blocklist")
            return packet

        if packet['dst_ip'] in self.sensitive_servers and not self._is_internal_ip(packet['src_ip']):
            if packet['dst_port'] not in [80, 443, 22]:
                packet['rule_result'] = "BLOCKED"
                packet['rule_reason'] = f"Unauthorized access to sensitive server port {packet['dst_port']}"
                logging.info(f"[STEP 2] BLOCKED packet to sensitive server {packet['dst_ip']}:{packet['dst_port']} from external {packet['src_ip']}")
                return packet

        if packet['dst_port'] == 23 and not self._is_internal_ip(packet['src_ip']):
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = "Telnet blocked from external sources"
            logging.info(f"[STEP 2] BLOCKED telnet from external {packet['src_ip']}")
            return packet

        db_ports = [3306, 1433, 5432, 27017]
        if packet['dst_port'] in db_ports and not self._is_internal_ip(packet['src_ip']):
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = f"External access to database port {packet['dst_port']}"
            logging.info(f"[STEP 2] BLOCKED external access to DB port {packet['dst_port']} from {packet['src_ip']}")
            return packet

        self.ip_connection_counts[packet['src_ip']] += 1
        if self.ip_connection_counts[packet['src_ip']] > 500:
            packet['rule_result'] = "SUSPICIOUS"
            packet['rule_reason'] = "High connection rate"
            logging.warning(f"[STEP 2] SUSPICIOUS - High connection rate from {packet['src_ip']}")
            return packet

        packet['rule_result'] = "PASSED"
        packet['rule_reason'] = "Passed rule inspection"
        return packet

    def _step3_anomaly_detection(self, packet):

        if packet['rule_result'] == "BLOCKED":
            return packet

        features = self._extract_features(packet)

        features_scaled = self.scaler.transform(features.reshape(1, -1))


        anomaly_score = self.anomaly_model.decision_function(features_scaled)[0]
        anomaly_prediction = self.anomaly_model.predict(features_scaled)[0]

        packet['anomaly_score'] = anomaly_score


        if anomaly_prediction == -1:
            packet['anomaly_result'] = "ANOMALOUS"
            logging.warning(f"[STEP 3] ANOMALOUS packet detected: {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}, Score: {anomaly_score:.4f}")
        else:
            packet['anomaly_result'] = "NORMAL"

        return packet

    def _step4_context_response(self, packet):

        if packet['rule_result'] == "BLOCKED":
            self.blocked_count += 1
            packet['final_action'] = "BLOCKED"
            return packet

        if packet['anomaly_result'] == "ANOMALOUS":
            connection_key = f"{packet['src_ip']}:{packet['dst_ip']}"

            if connection_key in self.suspicious_connections:
                packet['final_action'] = "BLOCKED"
                packet['context_reason'] = "Recurring suspicious activity"
                self.blocked_count += 1
                logging.warning(f"[STEP 4] BLOCKED recurring suspicious activity from {packet['src_ip']}")

                self.alerts.append({
                    'timestamp': packet['timestamp'],
                    'src_ip': packet['src_ip'],
                    'dst_ip': packet['dst_ip'],
                    'alert_type': 'RECURRING_SUSPICIOUS',
                    'score': packet['anomaly_score'],
                    'action': 'BLOCKED'
                })
            else:
                packet['final_action'] = "ALLOWED_WITH_WARNING"
                packet['context_reason'] = "First-time suspicious activity"
                self.suspicious_count += 1
                logging.warning(f"[STEP 4] ALLOWED WITH WARNING first-time suspicious from {packet['src_ip']}")

                self.suspicious_connections.add(connection_key)

                self.alerts.append({
                    'timestamp': packet['timestamp'],
                    'src_ip': packet['src_ip'],
                    'dst_ip': packet['dst_ip'],
                    'alert_type': 'NEW_SUSPICIOUS',
                    'score': packet['anomaly_score'],
                    'action': 'WARNED'
                })

        elif packet['rule_result'] == "SUSPICIOUS":
            packet['final_action'] = "ALLOWED_WITH_WARNING"
            packet['context_reason'] = packet['rule_reason']
            self.suspicious_count += 1
            logging.warning(f"[STEP 4] ALLOWED WITH WARNING - {packet['rule_reason']} from {packet['src_ip']}")

        else:
            packet['final_action'] = "ALLOWED"
            packet['context_reason'] = "Normal traffic"
            self.allowed_count += 1

        return packet

    def _step5_final_output(self, packet):

        action = packet['final_action']

        if action == "BLOCKED":
            message = f"BLOCKED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}"
            if 'context_reason' in packet:
                message += f" Reason: {packet['context_reason']}"
            elif 'rule_reason' in packet:
                message += f" Reason: {packet['rule_reason']}"
            logging.info(f"[STEP 5] {message}")

        elif action == "ALLOWED_WITH_WARNING":
            message = f"WARNED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}"
            if 'context_reason' in packet:
                message += f" Reason: {packet['context_reason']}"
            logging.info(f"[STEP 5] {message}")

        elif action == "ALLOWED":
            logging.debug(f"[STEP 5] ALLOWED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}")

        return packet

    def process_packet(self, packet):

        packet = self._step1_data_input(packet)

        packet = self._step2_rule_inspection(packet)

        packet = self._step3_anomaly_detection(packet)

        packet = self._step4_context_response(packet)

        packet = self._step5_final_output(packet)

        return packet

    def _is_internal_ip(self, ip):
        try:
            return ipaddress.IPv4Address(ip) in self.internal_network or ipaddress.IPv4Address(ip) in self.dmz_network
        except:
            return False

    def _extract_features(self, packet):

        hour = datetime.datetime.now().hour / 24.0

        src_ip = packet['src_ip']
        if src_ip not in self.connection_history:
            self.connection_history[src_ip] = {
                'last_seen': time.time(),
                'packet_sizes': [packet['size']],
                'ports_accessed': [packet['dst_port']]
            }
            packet_rate = 0.1
            connection_duration = 0.1
            port_entropy = 0.0
        else:
            history = self.connection_history[src_ip]
            current_time = time.time()


            time_diff = current_time - history['last_seen']
            history['last_seen'] = current_time

            history['packet_sizes'].append(packet['size'])
            if len(history['packet_sizes']) > 100:
                history['packet_sizes'] = history['packet_sizes'][-100:]


            history['ports_accessed'].append(packet['dst_port'])
            if len(history['ports_accessed']) > 100:
                history['ports_accessed'] = history['ports_accessed'][-100:]

            packet_rate = 1.0 / max(time_diff, 0.1)

            connection_duration = 10.0

            port_counts = Counter(history['ports_accessed'])
            total_ports = len(history['ports_accessed'])
            port_entropy = 0.0
            for port, count in port_counts.items():
                p = count / total_ports
                port_entropy -= p * np.log2(p)


        return np.array([
            packet['size'],
            packet_rate,
            connection_duration,
            port_entropy,
            hour
        ])

    def generate_reports(self):
        stats = {
            'total_packets': self.total_packets,
            'allowed': self.allowed_count,
            'blocked': self.blocked_count,
            'suspicious': self.suspicious_count,
            'alert_count': len(self.alerts),
            'unique_sources': len(set(log['src_ip'] for log in self.traffic_logs)),
            'unique_destinations': len(set(log['dst_ip'] for log in self.traffic_logs))
        }


        if self.total_packets > 0:
            stats['allowed_percentage'] = (self.allowed_count / self.total_packets) * 100
            stats['blocked_percentage'] = (self.blocked_count / self.total_packets) * 100
            stats['suspicious_percentage'] = (self.suspicious_count / self.total_packets) * 100
        else:
            stats['allowed_percentage'] = 0
            stats['blocked_percentage'] = 0
            stats['suspicious_percentage'] = 0


        src_counts = Counter(log['src_ip'] for log in self.traffic_logs)
        dst_counts = Counter(log['dst_ip'] for log in self.traffic_logs)
        port_counts = Counter(log['dst_port'] for log in self.traffic_logs)

        stats['top_sources'] = src_counts.most_common(5)
        stats['top_destinations'] = dst_counts.most_common(5)
        stats['top_ports'] = [(port, count, self.common_ports.get(port, "Unknown"))
                            for port, count in port_counts.most_common(5)]


        logs_df = pd.DataFrame(self.traffic_logs)


        return stats, logs_df

    def plot_traffic_summary(self, logs_df):

        plt.figure(figsize=(15, 10))


        plt.subplot(2, 2, 1)
        action_counts = logs_df['final_action'].value_counts()
        plt.pie(action_counts, labels=action_counts.index, autopct='%1.1f%%',
                colors=['green', 'red', 'orange'] if 'ALLOWED_WITH_WARNING' in action_counts.index else ['green', 'red'])
        plt.title('Traffic Action Distribution')


        plt.subplot(2, 2, 2)
        top_sources = logs_df['src_ip'].value_counts().head(10)
        top_sources.plot(kind='barh')
        plt.title('Top 10 Source IPs')
        plt.xlabel('Packet Count')
        plt.ylabel('Source IP')
        plt.tight_layout()


        plt.subplot(2, 2, 3)
        top_ports = logs_df['dst_port'].value_counts().head(10)
        top_ports.plot(kind='barh')
        plt.title('Top 10 Destination Ports')
        plt.xlabel('Packet Count')
        plt.ylabel('Destination Port')


        plt.subplot(2, 2, 4)
        if 'anomaly_score' in logs_df.columns:
            sns.histplot(logs_df['anomaly_score'].dropna(), kde=True)
            plt.title('Anomaly Score Distribution')
            plt.xlabel('Anomaly Score')
            plt.ylabel('Frequency')
        else:
            plt.text(0.5, 0.5, 'No anomaly scores available',
                     horizontalalignment='center', verticalalignment='center')
            plt.title('Anomaly Score Distribution')

        plt.tight_layout()
        plt.savefig('firewall_traffic_summary.png')
        plt.close()


        if 'timestamp' in logs_df.columns:
            try:
                logs_df['timestamp'] = pd.to_datetime(logs_df['timestamp'])
                logs_df.set_index('timestamp', inplace=True)


                traffic_by_time = logs_df.resample('1min').size()

                plt.figure(figsize=(12, 6))
                traffic_by_time.plot()
                plt.title('Traffic Volume Over Time')
                plt.xlabel('Time')
                plt.ylabel('Packet Count')
                plt.tight_layout()
                plt.savefig('traffic_over_time.png')
                plt.close()
            except:
                logging.warning("Could not generate time-based traffic plot")

def generate_synthetic_packet():

    internal_ips = [f"192.168.1.{i}" for i in range(1, 50)]
    external_ips = [
        "203.0.113.45", "198.51.100.67", "8.8.8.8", "1.1.1.1",
        "185.174.102.56", "91.213.8.43", "45.95.147.23", "65.21.54.1",
        "104.21.31.84", "172.67.169.39", "140.82.121.4", "35.227.248.234",
        "185.180.12.15", "103.43.141.122", "194.36.189.51", "5.255.96.50"
    ]

    dmz_ips = [f"172.16.1.{i}" for i in range(1, 10)]

    common_ports = [21, 22, 23, 25, 53, 80, 443, 3306, 3389, 445, 8080, 8443]


    direction_roll = random.random()

    if direction_roll < 0.4:
        src_ip = random.choice(internal_ips)
        dst_ip = random.choice(external_ips)
    elif direction_roll < 0.7:
        src_ip = random.choice(external_ips)
        dst_ip = random.choice(internal_ips + dmz_ips)
    elif direction_roll < 0.9:
        src_ip = random.choice(internal_ips)
        dst_ip = random.choice(internal_ips + dmz_ips)
    else:
        src_ip = random.choice(dmz_ips)
        dst_ip = random.choice(internal_ips + external_ips)


    is_attack = random.random() < 0.05

    if is_attack:

        packet_size = random.randint(1500, 65000)


        if random.random() < 0.5:
            dst_port = random.randint(1024, 65535)
        else:
            dst_port = random.choice([3306, 1433, 5432, 23, 22])

        src_port = random.randint(10000, 65000)

    else:

        packet_size = random.randint(64, 1460)
        dst_port = random.choice(common_ports)
        src_port = random.randint(10000, 65000)


    packet = {
        'src_ip': src_ip,
        'src_port': src_port,
        'dst_ip': dst_ip,
        'dst_port': dst_port,
        'size': packet_size,
        'protocol': random.choice(['TCP', 'UDP', 'ICMP']),
        'flags': random.choice(['SYN', 'ACK', 'SYN-ACK', 'FIN', 'RST', 'NONE']),
    }

    return packet

def run_simulation(duration_seconds=60, packets_per_second=10):

    firewall = NetworkFirewall()

    total_packets = duration_seconds * packets_per_second
    start_time = time.time()

    logging.info(f"Starting simulation - Processing {total_packets} packets over {duration_seconds} seconds")

    try:
        for _ in tqdm(range(total_packets), desc="Processing packets"):

            packet = generate_synthetic_packet()

            firewall.process_packet(packet)

            sleep_time = max(0, random.normalvariate(1.0 / packets_per_second, 0.01))
            time.sleep(sleep_time)

    except KeyboardInterrupt:
        logging.info("Simulation interrupted by user")

    end_time = time.time()
    actual_duration = end_time - start_time
    actual_rate = firewall.total_packets / actual_duration

    logging.info(f"Simulation complete - Processed {firewall.total_packets} packets in {actual_duration:.2f} seconds ({actual_rate:.2f} packets/sec)")

    stats, logs_df = firewall.generate_reports()

    firewall.plot_traffic_summary(logs_df)

    return firewall, stats, logs_df

def display_simulation_results(stats, logs_df):

    print("\n" + "="*80)
    print(" "*30 + "SIMULATION RESULTS")
    print("="*80)


    print("\n[TRAFFIC STATISTICS]")
    print(f"Total Packets Processed: {stats['total_packets']}")
    print(f"Allowed Packets: {stats['allowed']} ({stats['allowed_percentage']:.2f}%)")
    print(f"Blocked Packets: {stats['blocked']} ({stats['blocked_percentage']:.2f}%)")
    print(f"Suspicious Packets: {stats['suspicious']} ({stats['suspicious_percentage']:.2f}%)")
    print(f"Unique Source IPs: {stats['unique_sources']}")
    print(f"Unique Destination IPs: {stats['unique_destinations']}")
    print(f"Total Security Alerts: {stats['alert_count']}")

    print("\n[TOP 5 TRAFFIC SOURCES]")
    for ip, count in stats['top_sources']:
        print(f"{ip}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[TOP 5 TRAFFIC DESTINATIONS]")
    for ip, count in stats['top_destinations']:
        print(f"{ip}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[TOP 5 DESTINATION PORTS]")
    for port, count, service in stats['top_ports']:
        print(f"Port {port} ({service}): {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[PACKET ACTION DISTRIBUTION]")
    action_counts = logs_df['final_action'].value_counts()
    for action, count in action_counts.items():
        print(f"{action}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    if 'anomaly_score' in logs_df.columns:
        print("\n[ANOMALY SCORE STATISTICS]")
        anomaly_stats = logs_df['anomaly_score'].describe()
        print(f"Mean Anomaly Score: {anomaly_stats['mean']:.4f}")
        print(f"Min Anomaly Score: {anomaly_stats['min']:.4f}")
        print(f"Max Anomaly Score: {anomaly_stats['max']:.4f}")
        print(f"25th Percentile: {anomaly_stats['25%']:.4f}")
        print(f"Median Anomaly Score: {anomaly_stats['50%']:.4f}")
        print(f"75th Percentile: {anomaly_stats['75%']:.4f}")

    print("\n" + "="*80)
    print("Visualization files created:")
    print("- firewall_traffic_summary.png - Summary of traffic patterns")
    print("- traffic_over_time.png - Traffic volume over time")
    print("="*80 + "\n")


if __name__ == "__main__":
    print("\n" + "="*80)
    print(" "*25 + "NETWORK FIREWALL SIMULATION")
    print("="*80)
    print("\nSimulation Setup:")
    print("- Framework: Custom Python implementation")
    print("- Components: Data Input -> Rule Inspection -> Anomaly Detection -> Context Response -> Final Output")
    print("- Attack Simulation: 5% of traffic is attack/anomalous")
    print("- Real IP Addresses: Using realistic internal, DMZ, and external IP ranges")
    print("- ML Algorithm: Isolation Forest for anomaly detection")
    print("- Duration: 60 seconds")
    print("- Traffic Rate: 10 packets per second")
    print("\nStarting simulation...")


    firewall, stats, logs_df = run_simulation(duration_seconds=60, packets_per_second=10)

    display_simulation_results(stats, logs_df)
# Out:
# ================================================================================
#                          NETWORK FIREWALL SIMULATION
# ================================================================================
#
# Simulation Setup:
# - Framework: Custom Python implementation
# - Components: Data Input -> Rule Inspection -> Anomaly Detection -> Context Response -> Final Output
# - Attack Simulation: 5% of traffic is attack/anomalous
# - Real IP Addresses: Using realistic internal, DMZ, and external IP ranges
# - ML Algorithm: Isolation Forest for anomaly detection
# - Duration: 60 seconds
# - Traffic Rate: 10 packets per second
#
# Starting simulation...
# Processing packets:   0%|          | 1/600 [00:00<02:09,  4.62it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.31:23375 -> 203.0.113.45:445, Score: -0.0032
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.31
# Processing packets:   0%|          | 3/600 [00:00<01:46,  5.60it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:12351 -> 198.51.100.67:23, Score: -0.0032
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:   1%|          | 4/600 [00:00<01:46,  5.57it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 140.82.121.4:28583 -> 192.168.1.26:443, Score: -0.0200
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 140.82.121.4
# Processing packets:   1%|          | 7/600 [00:01<01:41,  5.82it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.1:52174 -> 192.168.1.16:26562, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.1
# Processing packets:   2%|▏         | 13/600 [00:02<01:22,  7.10it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:36329 -> 192.168.1.3:21, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:   2%|▏         | 14/600 [00:02<01:25,  6.82it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.12:15427 -> 192.168.1.25:21, Score: -0.0208
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.12
# Processing packets:   2%|▎         | 15/600 [00:02<01:32,  6.32it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.42:22115 -> 192.168.1.48:53, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.42
# Processing packets:   3%|▎         | 17/600 [00:02<01:32,  6.27it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:46648 -> 192.168.1.19:80, Score: -0.0379
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:   3%|▎         | 18/600 [00:02<01:32,  6.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.40:46786 -> 192.168.1.3:53, Score: -0.0081
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.40
# Processing packets:   3%|▎         | 20/600 [00:03<01:51,  5.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 198.51.100.67:24997 -> 192.168.1.9:8443, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 198.51.100.67
# Processing packets:   4%|▍         | 23/600 [00:03<01:45,  5.46it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:57765 -> 185.174.102.56:23, Score: -0.0370
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:   4%|▍         | 25/600 [00:04<01:38,  5.85it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:22322 -> 192.168.1.18:23, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:   5%|▍         | 29/600 [00:04<01:33,  6.09it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:46222 -> 91.213.8.43:445, Score: -0.0060
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:   5%|▌         | 32/600 [00:05<01:43,  5.51it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:13064 -> 172.16.1.4:21, Score: -0.0336
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:   6%|▌         | 35/600 [00:06<02:08,  4.40it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:15435 -> 172.67.169.39:8080, Score: -0.0060
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:   6%|▌         | 36/600 [00:06<02:06,  4.47it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.30:20789 -> 192.168.1.44:8080, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.30
# Processing packets:   6%|▋         | 38/600 [00:06<01:40,  5.60it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:41102 -> 185.180.12.15:443, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:   6%|▋         | 39/600 [00:06<01:42,  5.49it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.41:33527 -> 8.8.8.8:25, Score: -0.0125
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.41
# Processing packets:   7%|▋         | 40/600 [00:07<01:44,  5.34it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.24:20857 -> 198.51.100.67:3389, Score: -0.0280
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.24
# Processing packets:   8%|▊         | 46/600 [00:08<01:49,  5.05it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.40:41506 -> 192.168.1.34:25, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.40
# Processing packets:   9%|▊         | 52/600 [00:09<01:32,  5.94it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.17:32854 -> 194.36.189.51:23, Score: -0.0081
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.17
# Processing packets:   9%|▉         | 54/600 [00:09<01:30,  6.06it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.36:45014 -> 192.168.1.16:25, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.36
# Processing packets:  10%|▉         | 58/600 [00:10<01:29,  6.03it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:45321 -> 192.168.1.8:22, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:  10%|▉         | 59/600 [00:10<01:29,  6.07it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.25:49717 -> 45.95.147.23:8443, Score: -0.0032
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.25
# Processing packets:  10%|█         | 60/600 [00:10<01:32,  5.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.5:28999 -> 91.213.8.43:8080, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.5
# Processing packets:  12%|█▏        | 69/600 [00:12<01:25,  6.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.1:14652 -> 192.168.1.32:53, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.1
# Processing packets:  12%|█▏        | 73/600 [00:12<01:21,  6.47it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:63997 -> 91.213.8.43:443, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:  13%|█▎        | 78/600 [00:13<01:29,  5.81it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.35:18939 -> 65.21.54.1:40927, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.35
# Processing packets:  13%|█▎        | 79/600 [00:13<01:26,  6.01it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.23:39330 -> 172.16.1.6:23, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.23
# Processing packets:  14%|█▎        | 81/600 [00:14<01:29,  5.79it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.2:52583 -> 65.21.54.1:1433, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.2
# Processing packets:  14%|█▎        | 82/600 [00:14<01:47,  4.83it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.6:36229 -> 192.168.1.15:8443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.6
# Processing packets:  14%|█▍        | 85/600 [00:14<01:24,  6.08it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.24:39040 -> 198.51.100.67:80, Score: -0.0097
# WARNING:root:[STEP 4] BLOCKED recurring suspicious activity from 192.168.1.24
# Processing packets:  15%|█▍        | 89/600 [00:15<01:07,  7.58it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.18:21568 -> 172.16.1.3:23, Score: -0.0394
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.18
# Processing packets:  16%|█▌        | 93/600 [00:15<01:03,  8.04it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:16757 -> 192.168.1.26:3389, Score: -0.0056
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:  16%|█▌        | 96/600 [00:16<00:59,  8.44it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:33533 -> 172.16.1.1:8443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:  16%|█▋        | 99/600 [00:16<01:02,  7.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.29:53002 -> 192.168.1.46:21, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.29
# Processing packets:  17%|█▋        | 103/600 [00:16<00:59,  8.29it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.16:23320 -> 172.16.1.9:23, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.16
# Processing packets:  18%|█▊        | 107/600 [00:17<01:03,  7.76it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.41:62291 -> 140.82.121.4:27159, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.41
# Processing packets:  20%|█▉        | 118/600 [00:18<00:54,  8.81it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 104.21.31.84:32265 -> 192.168.1.36:1637, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 104.21.31.84
# Processing packets:  21%|██▏       | 128/600 [00:20<01:03,  7.46it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.28:35720 -> 172.16.1.9:443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.28
# Processing packets:  22%|██▏       | 129/600 [00:20<01:04,  7.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.37:62027 -> 172.16.1.6:443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.37
# Processing packets:  22%|██▏       | 130/600 [00:20<01:02,  7.51it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.28:24921 -> 203.0.113.45:57238, Score: -0.0072
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.28
# Processing packets:  23%|██▎       | 136/600 [00:21<01:05,  7.10it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.9:53494 -> 140.82.121.4:25, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.9
# Processing packets:  23%|██▎       | 139/600 [00:21<00:59,  7.81it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:46070 -> 185.174.102.56:25, Score: -0.0336
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  24%|██▍       | 146/600 [00:22<00:56,  8.01it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:35042 -> 198.51.100.67:443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.43
# Processing packets:  25%|██▌       | 150/600 [00:22<00:57,  7.80it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.20:16159 -> 198.51.100.67:3389, Score: -0.0163
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.20
# Processing packets:  25%|██▌       | 152/600 [00:23<00:52,  8.48it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:63206 -> 192.168.1.14:24812, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  26%|██▌       | 154/600 [00:23<00:56,  7.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:51869 -> 185.174.102.56:8080, Score: -0.0379
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:  28%|██▊       | 167/600 [00:25<00:51,  8.37it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.25:36881 -> 172.67.169.39:80, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.25
# Processing packets:  28%|██▊       | 168/600 [00:25<00:52,  8.27it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.14:38417 -> 192.168.1.25:8443, Score: -0.0072
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.14
# Processing packets:  29%|██▉       | 173/600 [00:25<00:56,  7.55it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.32:38896 -> 1.1.1.1:23, Score: -0.0379
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.32
# Processing packets:  30%|███       | 182/600 [00:26<00:49,  8.43it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.45:56165 -> 192.168.1.19:80, Score: -0.0332
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.45
# Processing packets:  30%|███       | 183/600 [00:26<00:48,  8.56it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:18929 -> 172.16.1.5:21, Score: -0.0085
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:  31%|███▏      | 188/600 [00:27<00:48,  8.53it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.7:27523 -> 203.0.113.45:445, Score: -0.0072
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.7
# Processing packets:  32%|███▏      | 191/600 [00:27<00:50,  8.17it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.6:58144 -> 192.168.1.40:8443, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.6
# Processing packets:  32%|███▏      | 192/600 [00:28<00:49,  8.18it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:50830 -> 192.168.1.15:56112, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:  34%|███▍      | 204/600 [00:29<00:48,  8.18it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.10:10535 -> 35.227.248.234:445, Score: -0.0044
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.10
# Processing packets:  35%|███▍      | 209/600 [00:30<00:48,  8.05it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.6:51510 -> 192.168.1.16:3389, Score: -0.0032
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.6
# Processing packets:  35%|███▌      | 211/600 [00:30<00:49,  7.92it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:19461 -> 5.255.96.50:1433, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.43
# Processing packets:  36%|███▌      | 213/600 [00:30<00:48,  7.92it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.45:43521 -> 185.174.102.56:3306, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.45
# Processing packets:  36%|███▌      | 215/600 [00:30<00:47,  8.09it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.34:19537 -> 192.168.1.1:22, Score: -0.0056
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.34
# Processing packets:  40%|████      | 243/600 [00:34<00:45,  7.88it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.32:27242 -> 192.168.1.23:445, Score: -0.0118
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.32
# Processing packets:  43%|████▎     | 257/600 [00:36<00:40,  8.45it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.1:63884 -> 5.255.96.50:445, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.1
# Processing packets:  44%|████▎     | 261/600 [00:36<00:40,  8.34it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.27:43131 -> 185.180.12.15:22, Score: -0.0098
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.27
# Processing packets:  46%|████▋     | 279/600 [00:38<00:39,  8.08it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.18:42948 -> 8.8.8.8:80, Score: -0.0118
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.18
# Processing packets:  49%|████▉     | 293/600 [00:40<00:37,  8.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:40006 -> 192.168.1.32:443, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:  54%|█████▍    | 323/600 [00:44<00:33,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:24218 -> 172.67.169.39:21, Score: -0.0015
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  56%|█████▌    | 334/600 [00:45<00:33,  7.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:54014 -> 192.168.1.9:21, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:  58%|█████▊    | 348/600 [00:47<00:33,  7.61it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.15:49409 -> 5.255.96.50:23, Score: -0.0387
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.15
# Processing packets:  58%|█████▊    | 350/600 [00:47<00:32,  7.70it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:54861 -> 192.168.1.18:8443, Score: -0.0060
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:  59%|█████▉    | 353/600 [00:47<00:31,  7.89it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:60912 -> 65.21.54.1:3306, Score: -0.0032
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:  61%|██████    | 365/600 [00:49<00:28,  8.29it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.48:27726 -> 185.180.12.15:21, Score: -0.0068
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.48
# Processing packets:  62%|██████▏   | 370/600 [00:50<00:28,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:45612 -> 104.21.31.84:8443, Score: -0.0015
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:  62%|██████▎   | 375/600 [00:50<00:25,  8.66it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.1:54207 -> 192.168.1.22:25, Score: -0.0163
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.1
# Processing packets:  64%|██████▎   | 382/600 [00:51<00:27,  7.99it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.48:32304 -> 192.168.1.19:3306, Score: -0.0007
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.48
# Processing packets:  64%|██████▍   | 387/600 [00:52<00:26,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.28:16213 -> 198.51.100.67:8080, Score: -0.0068
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.28
# Processing packets:  67%|██████▋   | 401/600 [00:53<00:22,  8.71it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.39:36005 -> 172.16.1.7:3306, Score: -0.0034
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.39
# Processing packets:  67%|██████▋   | 402/600 [00:53<00:22,  8.71it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.15:36300 -> 5.255.96.50:3389, Score: -0.0084
# WARNING:root:[STEP 4] BLOCKED recurring suspicious activity from 192.168.1.15
# Processing packets:  68%|██████▊   | 405/600 [00:54<00:23,  8.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 8.8.8.8:51906 -> 192.168.1.17:445, Score: -0.0023
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 8.8.8.8
# Processing packets:  68%|██████▊   | 410/600 [00:54<00:21,  8.80it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.3:25304 -> 45.95.147.23:22, Score: -0.0400
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.3
# Processing packets:  70%|██████▉   | 419/600 [00:55<00:21,  8.37it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:29595 -> 192.168.1.30:53, Score: -0.0114
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  72%|███████▏  | 431/600 [00:57<00:20,  8.13it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.3:54760 -> 192.168.1.11:53, Score: -0.0084
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.3
# Processing packets:  73%|███████▎  | 438/600 [00:58<00:19,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:34174 -> 172.67.169.39:80, Score: -0.0142
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:  76%|███████▋  | 459/600 [01:00<00:17,  8.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:26823 -> 192.168.1.15:80, Score: -0.0334
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  77%|███████▋  | 463/600 [01:01<00:17,  7.75it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 198.51.100.67:63067 -> 172.16.1.8:443, Score: -0.0001
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 198.51.100.67
# Processing packets:  79%|███████▉  | 476/600 [01:02<00:13,  9.32it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:43700 -> 172.16.1.7:80, Score: -0.0024
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  82%|████████▏ | 490/600 [01:04<00:13,  7.90it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:38949 -> 103.43.141.122:443, Score: -0.0036
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:  82%|████████▏ | 491/600 [01:04<00:13,  8.13it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.1:25775 -> 192.168.1.34:21, Score: -0.0079
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.1
# Processing packets:  85%|████████▌ | 512/600 [01:07<00:10,  8.50it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:31897 -> 192.168.1.22:445, Score: -0.0122
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:  86%|████████▌ | 516/600 [01:07<00:10,  7.66it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:58797 -> 65.21.54.1:53, Score: -0.0289
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:  87%|████████▋ | 523/600 [01:08<00:09,  8.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.5:38904 -> 192.168.1.48:445, Score: -0.0334
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.5
# Processing packets:  88%|████████▊ | 529/600 [01:09<00:08,  8.68it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.67.169.39:37112 -> 172.16.1.6:53, Score: -0.0030
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.67.169.39
# Processing packets:  89%|████████▉ | 536/600 [01:09<00:07,  8.95it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:25426 -> 192.168.1.40:8080, Score: -0.0049
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:  90%|████████▉ | 538/600 [01:10<00:07,  8.33it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:44828 -> 192.168.1.29:25, Score: -0.0023
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:  92%|█████████▏| 550/600 [01:11<00:05,  8.63it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:17461 -> 192.168.1.32:53, Score: -0.0036
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:  92%|█████████▏| 554/600 [01:12<00:05,  8.78it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.17:47970 -> 8.8.8.8:8443, Score: -0.0068
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.17
# Processing packets:  94%|█████████▍| 563/600 [01:13<00:04,  8.00it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:30641 -> 192.168.1.17:5432, Score: -0.0338
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:  96%|█████████▌| 576/600 [01:14<00:02,  8.37it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:49770 -> 192.168.1.16:12370, Score: -0.0402
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  97%|█████████▋| 584/600 [01:15<00:01,  8.66it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.5:44071 -> 192.168.1.42:21, Score: -0.0109
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.5
# Processing packets:  98%|█████████▊| 585/600 [01:15<00:01,  8.49it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:47554 -> 185.180.12.15:8443, Score: -0.0389
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:  98%|█████████▊| 590/600 [01:16<00:01,  8.13it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:47802 -> 192.168.1.36:80, Score: -0.0244
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  98%|█████████▊| 591/600 [01:16<00:01,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:59340 -> 192.168.1.3:53, Score: -0.0264
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  99%|█████████▉| 595/600 [01:16<00:00,  8.80it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:39459 -> 192.168.1.29:3389, Score: -0.0030
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:  99%|█████████▉| 596/600 [01:17<00:00,  8.89it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.2:48861 -> 192.168.1.12:3389, Score: -0.0167
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.2
# Processing packets: 100%|██████████| 600/600 [01:17<00:00,  7.74it/s]
# ================================================================================
#                               SIMULATION RESULTS
# ================================================================================
#
# [TRAFFIC STATISTICS]
# Total Packets Processed: 600
# Allowed Packets: 404 (67.33%)
# Blocked Packets: 94 (15.67%)
# Suspicious Packets: 102 (17.00%)
# Unique Source IPs: 74
# Unique Destination IPs: 74
# Total Security Alerts: 104
#
# [TOP 5 TRAFFIC SOURCES]
# 65.21.54.1: 20 packets (3.33%)
# 5.255.96.50: 16 packets (2.67%)
# 172.16.1.8: 13 packets (2.17%)
# 203.0.113.45: 13 packets (2.17%)
# 192.168.1.36: 13 packets (2.17%)
#
# [TOP 5 TRAFFIC DESTINATIONS]
# 203.0.113.45: 23 packets (3.83%)
# 5.255.96.50: 21 packets (3.50%)
# 65.21.54.1: 18 packets (3.00%)
# 104.21.31.84: 18 packets (3.00%)
# 194.36.189.51: 18 packets (3.00%)
#
# [TOP 5 DESTINATION PORTS]
# Port 21 (FTP Control): 61 packets (10.17%)
# Port 445 (SMB): 58 packets (9.67%)
# Port 443 (HTTPS): 53 packets (8.83%)
# Port 53 (DNS): 52 packets (8.67%)
# Port 3389 (RDP): 51 packets (8.50%)
#
# [PACKET ACTION DISTRIBUTION]
# ALLOWED: 404 packets (67.33%)
# ALLOWED_WITH_WARNING: 102 packets (17.00%)
# BLOCKED: 94 packets (15.67%)
#
# [ANOMALY SCORE STATISTICS]
# Mean Anomaly Score: 0.0360
# Min Anomaly Score: -0.0402
# Max Anomaly Score: 0.1276
# 25th Percentile: 0.0076
# Median Anomaly Score: 0.0278
# 75th Percentile: 0.0679
#
# ================================================================================
# Visualization files created:
# - firewall_traffic_summary.png - Summary of traffic patterns
# - traffic_over_time.png - Traffic volume over time
# ================================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import time
import ipaddress
import datetime
import logging
from collections import Counter
import random
from tqdm import tqdm

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("firewall_simulation.log"),
        logging.StreamHandler()
    ]
)

class NetworkFirewall:
    def __init__(self):
        self.common_ports = {
            20: "FTP Data", 21: "FTP Control", 22: "SSH", 23: "Telnet",
            25: "SMTP", 53: "DNS", 80: "HTTP", 443: "HTTPS",
            3306: "MySQL", 3389: "RDP", 445: "SMB", 1433: "SQL Server",
            8080: "HTTP Alt", 8443: "HTTPS Alt", 5900: "VNC"
        }

        self.blocked_count = 0
        self.allowed_count = 0
        self.suspicious_count = 0
        self.total_packets = 0

        self.blocked_ips = [
            "185.174.102.56", "91.213.8.43", "185.180.12.15",
            "103.43.141.122", "45.95.147.23", "198.12.64.10",
            "5.255.96.50", "185.159.128.78", "194.36.189.51"
        ]

        self.internal_network = ipaddress.IPv4Network("192.168.1.0/24")
        self.dmz_network = ipaddress.IPv4Network("172.16.1.0/24")
        self.sensitive_servers = ["192.168.1.10", "192.168.1.20", "172.16.1.5"]


        self.anomaly_model = None
        self.scaler = StandardScaler()
        self.connection_history = {}
        self.ip_connection_counts = Counter()


        self.alerts = []
        self.suspicious_connections = set()


        self.traffic_logs = []


        self._initialize_anomaly_model()

        logging.info("Network Firewall initialized successfully")

    def _initialize_anomaly_model(self):

        normal_data = self._generate_synthetic_training_data(5000)


        X_scaled = self.scaler.fit_transform(normal_data)


        self.anomaly_model = IsolationForest(
            n_estimators=100,
            max_samples='auto',
            contamination=0.01,
            random_state=42
        )
        self.anomaly_model.fit(X_scaled)

        logging.info("Anomaly detection model initialized and trained")

    def _generate_synthetic_training_data(self, n_samples):

        data = np.zeros((n_samples, 5))

        data[:, 0] = np.random.normal(500, 200, n_samples)


        data[:, 1] = np.random.normal(50, 20, n_samples)


        data[:, 2] = np.random.exponential(60, n_samples)


        data[:, 3] = np.random.normal(2, 0.5, n_samples)


        data[:, 4] = np.random.uniform(0, 24, n_samples) / 24.0

        return data

    def _step1_data_input(self, packet):

        self.total_packets += 1


        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")
        logging.debug(f"[STEP 1] Processing packet: {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']} ({packet['size']} bytes)")


        packet['timestamp'] = timestamp
        packet['packet_id'] = self.total_packets
        self.traffic_logs.append(packet)

        return packet

    def _step2_rule_inspection(self, packet):

        if packet['src_ip'] in self.blocked_ips:
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = "Source IP in blocklist"
            logging.info(f"[STEP 2] BLOCKED packet from {packet['src_ip']} - Source IP in blocklist")
            return packet

        if packet['dst_ip'] in self.sensitive_servers and not self._is_internal_ip(packet['src_ip']):
            if packet['dst_port'] not in [80, 443, 22]:
                packet['rule_result'] = "BLOCKED"
                packet['rule_reason'] = f"Unauthorized access to sensitive server port {packet['dst_port']}"
                logging.info(f"[STEP 2] BLOCKED packet to sensitive server {packet['dst_ip']}:{packet['dst_port']} from external {packet['src_ip']}")
                return packet

        if packet['dst_port'] == 23 and not self._is_internal_ip(packet['src_ip']):
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = "Telnet blocked from external sources"
            logging.info(f"[STEP 2] BLOCKED telnet from external {packet['src_ip']}")
            return packet

        db_ports = [3306, 1433, 5432, 27017]
        if packet['dst_port'] in db_ports and not self._is_internal_ip(packet['src_ip']):
            packet['rule_result'] = "BLOCKED"
            packet['rule_reason'] = f"External access to database port {packet['dst_port']}"
            logging.info(f"[STEP 2] BLOCKED external access to DB port {packet['dst_port']} from {packet['src_ip']}")
            return packet

        self.ip_connection_counts[packet['src_ip']] += 1
        if self.ip_connection_counts[packet['src_ip']] > 500:
            packet['rule_result'] = "SUSPICIOUS"
            packet['rule_reason'] = "High connection rate"
            logging.warning(f"[STEP 2] SUSPICIOUS - High connection rate from {packet['src_ip']}")
            return packet

        packet['rule_result'] = "PASSED"
        packet['rule_reason'] = "Passed rule inspection"
        return packet

    def _step3_anomaly_detection(self, packet):

        if packet['rule_result'] == "BLOCKED":
            return packet

        features = self._extract_features(packet)

        features_scaled = self.scaler.transform(features.reshape(1, -1))


        anomaly_score = self.anomaly_model.decision_function(features_scaled)[0]
        anomaly_prediction = self.anomaly_model.predict(features_scaled)[0]

        packet['anomaly_score'] = anomaly_score


        if anomaly_prediction == -1:
            packet['anomaly_result'] = "ANOMALOUS"
            logging.warning(f"[STEP 3] ANOMALOUS packet detected: {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}, Score: {anomaly_score:.4f}")
        else:
            packet['anomaly_result'] = "NORMAL"

        return packet

    def _step4_context_response(self, packet):

        if packet['rule_result'] == "BLOCKED":
            self.blocked_count += 1
            packet['final_action'] = "BLOCKED"
            return packet

        if packet['anomaly_result'] == "ANOMALOUS":
            connection_key = f"{packet['src_ip']}:{packet['dst_ip']}"

            if connection_key in self.suspicious_connections:
                packet['final_action'] = "BLOCKED"
                packet['context_reason'] = "Recurring suspicious activity"
                self.blocked_count += 1
                logging.warning(f"[STEP 4] BLOCKED recurring suspicious activity from {packet['src_ip']}")

                self.alerts.append({
                    'timestamp': packet['timestamp'],
                    'src_ip': packet['src_ip'],
                    'dst_ip': packet['dst_ip'],
                    'alert_type': 'RECURRING_SUSPICIOUS',
                    'score': packet['anomaly_score'],
                    'action': 'BLOCKED'
                })
            else:
                packet['final_action'] = "ALLOWED_WITH_WARNING"
                packet['context_reason'] = "First-time suspicious activity"
                self.suspicious_count += 1
                logging.warning(f"[STEP 4] ALLOWED WITH WARNING first-time suspicious from {packet['src_ip']}")

                self.suspicious_connections.add(connection_key)

                self.alerts.append({
                    'timestamp': packet['timestamp'],
                    'src_ip': packet['src_ip'],
                    'dst_ip': packet['dst_ip'],
                    'alert_type': 'NEW_SUSPICIOUS',
                    'score': packet['anomaly_score'],
                    'action': 'WARNED'
                })

        elif packet['rule_result'] == "SUSPICIOUS":
            packet['final_action'] = "ALLOWED_WITH_WARNING"
            packet['context_reason'] = packet['rule_reason']
            self.suspicious_count += 1
            logging.warning(f"[STEP 4] ALLOWED WITH WARNING - {packet['rule_reason']} from {packet['src_ip']}")

        else:
            packet['final_action'] = "ALLOWED"
            packet['context_reason'] = "Normal traffic"
            self.allowed_count += 1

        return packet

    def _step5_final_output(self, packet):

        action = packet['final_action']

        if action == "BLOCKED":
            message = f"BLOCKED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}"
            if 'context_reason' in packet:
                message += f" Reason: {packet['context_reason']}"
            elif 'rule_reason' in packet:
                message += f" Reason: {packet['rule_reason']}"
            logging.info(f"[STEP 5] {message}")

        elif action == "ALLOWED_WITH_WARNING":
            message = f"WARNED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}"
            if 'context_reason' in packet:
                message += f" Reason: {packet['context_reason']}"
            logging.info(f"[STEP 5] {message}")

        elif action == "ALLOWED":
            logging.debug(f"[STEP 5] ALLOWED {packet['src_ip']}:{packet['src_port']} -> {packet['dst_ip']}:{packet['dst_port']}")

        return packet

    def process_packet(self, packet):

        packet = self._step1_data_input(packet)

        packet = self._step2_rule_inspection(packet)

        packet = self._step3_anomaly_detection(packet)

        packet = self._step4_context_response(packet)

        packet = self._step5_final_output(packet)

        return packet

    def _is_internal_ip(self, ip):
        try:
            return ipaddress.IPv4Address(ip) in self.internal_network or ipaddress.IPv4Address(ip) in self.dmz_network
        except:
            return False

    def _extract_features(self, packet):

        hour = datetime.datetime.now().hour / 24.0

        src_ip = packet['src_ip']
        if src_ip not in self.connection_history:
            self.connection_history[src_ip] = {
                'last_seen': time.time(),
                'packet_sizes': [packet['size']],
                'ports_accessed': [packet['dst_port']]
            }
            packet_rate = 0.1
            connection_duration = 0.1
            port_entropy = 0.0
        else:
            history = self.connection_history[src_ip]
            current_time = time.time()


            time_diff = current_time - history['last_seen']
            history['last_seen'] = current_time

            history['packet_sizes'].append(packet['size'])
            if len(history['packet_sizes']) > 100:
                history['packet_sizes'] = history['packet_sizes'][-100:]


            history['ports_accessed'].append(packet['dst_port'])
            if len(history['ports_accessed']) > 100:
                history['ports_accessed'] = history['ports_accessed'][-100:]

            packet_rate = 1.0 / max(time_diff, 0.1)

            connection_duration = 10.0

            port_counts = Counter(history['ports_accessed'])
            total_ports = len(history['ports_accessed'])
            port_entropy = 0.0
            for port, count in port_counts.items():
                p = count / total_ports
                port_entropy -= p * np.log2(p)


        return np.array([
            packet['size'],
            packet_rate,
            connection_duration,
            port_entropy,
            hour
        ])

    def generate_reports(self):
        stats = {
            'total_packets': self.total_packets,
            'allowed': self.allowed_count,
            'blocked': self.blocked_count,
            'suspicious': self.suspicious_count,
            'alert_count': len(self.alerts),
            'unique_sources': len(set(log['src_ip'] for log in self.traffic_logs)),
            'unique_destinations': len(set(log['dst_ip'] for log in self.traffic_logs))
        }


        if self.total_packets > 0:
            stats['allowed_percentage'] = (self.allowed_count / self.total_packets) * 100
            stats['blocked_percentage'] = (self.blocked_count / self.total_packets) * 100
            stats['suspicious_percentage'] = (self.suspicious_count / self.total_packets) * 100
        else:
            stats['allowed_percentage'] = 0
            stats['blocked_percentage'] = 0
            stats['suspicious_percentage'] = 0


        src_counts = Counter(log['src_ip'] for log in self.traffic_logs)
        dst_counts = Counter(log['dst_ip'] for log in self.traffic_logs)
        port_counts = Counter(log['dst_port'] for log in self.traffic_logs)

        stats['top_sources'] = src_counts.most_common(5)
        stats['top_destinations'] = dst_counts.most_common(5)
        stats['top_ports'] = [(port, count, self.common_ports.get(port, "Unknown"))
                            for port, count in port_counts.most_common(5)]


        logs_df = pd.DataFrame(self.traffic_logs)


        return stats, logs_df

    def plot_traffic_summary(self, logs_df):

        plt.figure(figsize=(15, 10))


        plt.subplot(2, 2, 1)
        action_counts = logs_df['final_action'].value_counts()
        plt.pie(action_counts, labels=action_counts.index, autopct='%1.1f%%',
                colors=['green', 'red', 'orange'] if 'ALLOWED_WITH_WARNING' in action_counts.index else ['green', 'red'])
        plt.title('Traffic Action Distribution')


        plt.subplot(2, 2, 2)
        top_sources = logs_df['src_ip'].value_counts().head(10)
        top_sources.plot(kind='barh')
        plt.title('Top 10 Source IPs')
        plt.xlabel('Packet Count')
        plt.ylabel('Source IP')
        plt.tight_layout()


        plt.subplot(2, 2, 3)
        top_ports = logs_df['dst_port'].value_counts().head(10)
        top_ports.plot(kind='barh')
        plt.title('Top 10 Destination Ports')
        plt.xlabel('Packet Count')
        plt.ylabel('Destination Port')


        plt.subplot(2, 2, 4)
        if 'anomaly_score' in logs_df.columns:
            sns.histplot(logs_df['anomaly_score'].dropna(), kde=True)
            plt.title('Anomaly Score Distribution')
            plt.xlabel('Anomaly Score')
            plt.ylabel('Frequency')
        else:
            plt.text(0.5, 0.5, 'No anomaly scores available',
                     horizontalalignment='center', verticalalignment='center')
            plt.title('Anomaly Score Distribution')

        plt.tight_layout()
        plt.savefig('firewall_traffic_summary.png')
        plt.close()


        if 'timestamp' in logs_df.columns:
            try:
                logs_df['timestamp'] = pd.to_datetime(logs_df['timestamp'])
                logs_df.set_index('timestamp', inplace=True)


                traffic_by_time = logs_df.resample('1min').size()

                plt.figure(figsize=(12, 6))
                traffic_by_time.plot()
                plt.title('Traffic Volume Over Time')
                plt.xlabel('Time')
                plt.ylabel('Packet Count')
                plt.tight_layout()
                plt.savefig('traffic_over_time.png')
                plt.close()
            except:
                logging.warning("Could not generate time-based traffic plot")

# %%
def generate_synthetic_packet():

    internal_ips = [f"192.168.1.{i}" for i in range(1, 50)]
    external_ips = [
        "203.0.113.45", "198.51.100.67", "8.8.8.8", "1.1.1.1",
        "185.174.102.56", "91.213.8.43", "45.95.147.23", "65.21.54.1",
        "104.21.31.84", "172.67.169.39", "140.82.121.4", "35.227.248.234",
        "185.180.12.15", "103.43.141.122", "194.36.189.51", "5.255.96.50"
    ]

    dmz_ips = [f"172.16.1.{i}" for i in range(1, 10)]

    common_ports = [21, 22, 23, 25, 53, 80, 443, 3306, 3389, 445, 8080, 8443]


    direction_roll = random.random()

    if direction_roll < 0.4:
        src_ip = random.choice(internal_ips)
        dst_ip = random.choice(external_ips)
    elif direction_roll < 0.7:
        src_ip = random.choice(external_ips)
        dst_ip = random.choice(internal_ips + dmz_ips)
    elif direction_roll < 0.9:
        src_ip = random.choice(internal_ips)
        dst_ip = random.choice(internal_ips + dmz_ips)
    else:
        src_ip = random.choice(dmz_ips)
        dst_ip = random.choice(internal_ips + external_ips)


    is_attack = random.random() < 0.05

    if is_attack:

        packet_size = random.randint(1500, 65000)


        if random.random() < 0.5:
            dst_port = random.randint(1024, 65535)
        else:
            dst_port = random.choice([3306, 1433, 5432, 23, 22])

        src_port = random.randint(10000, 65000)

    else:

        packet_size = random.randint(64, 1460)
        dst_port = random.choice(common_ports)
        src_port = random.randint(10000, 65000)


    packet = {
        'src_ip': src_ip,
        'src_port': src_port,
        'dst_ip': dst_ip,
        'dst_port': dst_port,
        'size': packet_size,
        'protocol': random.choice(['TCP', 'UDP', 'ICMP']),
        'flags': random.choice(['SYN', 'ACK', 'SYN-ACK', 'FIN', 'RST', 'NONE']),
    }

    return packet

def run_simulation(duration_seconds=60, packets_per_second=10):

    firewall = NetworkFirewall()

    total_packets = duration_seconds * packets_per_second
    start_time = time.time()

    logging.info(f"Starting simulation - Processing {total_packets} packets over {duration_seconds} seconds")

    try:
        for _ in tqdm(range(total_packets), desc="Processing packets"):

            packet = generate_synthetic_packet()

            firewall.process_packet(packet)

            sleep_time = max(0, random.normalvariate(1.0 / packets_per_second, 0.01))
            time.sleep(sleep_time)

    except KeyboardInterrupt:
        logging.info("Simulation interrupted by user")

    end_time = time.time()
    actual_duration = end_time - start_time
    actual_rate = firewall.total_packets / actual_duration

    logging.info(f"Simulation complete - Processed {firewall.total_packets} packets in {actual_duration:.2f} seconds ({actual_rate:.2f} packets/sec)")

    stats, logs_df = firewall.generate_reports()

    firewall.plot_traffic_summary(logs_df)

    return firewall, stats, logs_df

# %%
def display_simulation_results(stats, logs_df):

    print("\n" + "="*80)
    print(" "*30 + "SIMULATION RESULTS")
    print("="*80)


    print("\n[TRAFFIC STATISTICS]")
    print(f"Total Packets Processed: {stats['total_packets']}")
    print(f"Allowed Packets: {stats['allowed']} ({stats['allowed_percentage']:.2f}%)")
    print(f"Blocked Packets: {stats['blocked']} ({stats['blocked_percentage']:.2f}%)")
    print(f"Suspicious Packets: {stats['suspicious']} ({stats['suspicious_percentage']:.2f}%)")
    print(f"Unique Source IPs: {stats['unique_sources']}")
    print(f"Unique Destination IPs: {stats['unique_destinations']}")
    print(f"Total Security Alerts: {stats['alert_count']}")

    print("\n[TOP 5 TRAFFIC SOURCES]")
    for ip, count in stats['top_sources']:
        print(f"{ip}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[TOP 5 TRAFFIC DESTINATIONS]")
    for ip, count in stats['top_destinations']:
        print(f"{ip}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[TOP 5 DESTINATION PORTS]")
    for port, count, service in stats['top_ports']:
        print(f"Port {port} ({service}): {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    print("\n[PACKET ACTION DISTRIBUTION]")
    action_counts = logs_df['final_action'].value_counts()
    for action, count in action_counts.items():
        print(f"{action}: {count} packets ({(count/stats['total_packets'])*100:.2f}%)")


    if 'anomaly_score' in logs_df.columns:
        print("\n[ANOMALY SCORE STATISTICS]")
        anomaly_stats = logs_df['anomaly_score'].describe()
        print(f"Mean Anomaly Score: {anomaly_stats['mean']:.4f}")
        print(f"Min Anomaly Score: {anomaly_stats['min']:.4f}")
        print(f"Max Anomaly Score: {anomaly_stats['max']:.4f}")
        print(f"25th Percentile: {anomaly_stats['25%']:.4f}")
        print(f"Median Anomaly Score: {anomaly_stats['50%']:.4f}")
        print(f"75th Percentile: {anomaly_stats['75%']:.4f}")

    print("\n" + "="*80)
    print("Visualization files created:")
    print("- firewall_traffic_summary.png - Summary of traffic patterns")
    print("- traffic_over_time.png - Traffic volume over time")
    print("="*80 + "\n")


if __name__ == "__main__":
    print("\n" + "="*80)
    print(" "*25 + "NETWORK FIREWALL SIMULATION")
    print("="*80)
    print("\nSimulation Setup:")
    print("- Framework: Custom Python implementation")
    print("- Components: Data Input -> Rule Inspection -> Anomaly Detection -> Context Response -> Final Output")
    print("- Attack Simulation: 5% of traffic is attack/anomalous")
    print("- Real IP Addresses: Using realistic internal, DMZ, and external IP ranges")
    print("- ML Algorithm: Isolation Forest for anomaly detection")
    print("- Duration: 60 seconds")
    print("- Traffic Rate: 10 packets per second")
    print("\nStarting simulation...")


    firewall, stats, logs_df = run_simulation(duration_seconds=60, packets_per_second=10)

    display_simulation_results(stats, logs_df)
# Out:
# ================================================================================
#                          NETWORK FIREWALL SIMULATION
# ================================================================================
#
# Simulation Setup:
# - Framework: Custom Python implementation
# - Components: Data Input -> Rule Inspection -> Anomaly Detection -> Context Response -> Final Output
# - Attack Simulation: 5% of traffic is attack/anomalous
# - Real IP Addresses: Using realistic internal, DMZ, and external IP ranges
# - ML Algorithm: Isolation Forest for anomaly detection
# - Duration: 60 seconds
# - Traffic Rate: 10 packets per second
#
# Starting simulation...
# Processing packets:   0%|          | 0/600 [00:00<?, ?it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:26905 -> 192.168.1.21:8080, Score: -0.0317
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:   0%|          | 1/600 [00:00<01:17,  7.69it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.15:56338 -> 104.21.31.84:22, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.15
# Processing packets:   0%|          | 2/600 [00:00<01:34,  6.34it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.3:47938 -> 65.21.54.1:3306, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.3
# Processing packets:   0%|          | 3/600 [00:00<01:34,  6.29it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.5:12750 -> 192.168.1.19:8080, Score: -0.0085
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.5
# Processing packets:   1%|          | 4/600 [00:00<01:42,  5.80it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.3:35601 -> 104.21.31.84:445, Score: -0.0336
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.3
# Processing packets:   1%|          | 6/600 [00:00<01:34,  6.27it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.34:41473 -> 185.180.12.15:8080, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.34
# Processing packets:   1%|▏         | 8/600 [00:01<01:35,  6.20it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.5:31565 -> 194.36.189.51:445, Score: -0.0013
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.5
# Processing packets:   2%|▏         | 10/600 [00:01<01:40,  5.88it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.30:15741 -> 172.67.169.39:23, Score: -0.0432
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.30
# Processing packets:   2%|▏         | 11/600 [00:01<01:49,  5.38it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.6:58620 -> 192.168.1.30:443, Score: -0.0374
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.6
# Processing packets:   2%|▏         | 14/600 [00:02<01:36,  6.06it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:20645 -> 194.36.189.51:80, Score: -0.0115
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:   2%|▎         | 15/600 [00:02<01:44,  5.59it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 35.227.248.234:23783 -> 192.168.1.22:8443, Score: -0.0495
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 35.227.248.234
# Processing packets:   3%|▎         | 16/600 [00:02<01:58,  4.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:52098 -> 172.16.1.4:8080, Score: -0.0144
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:   3%|▎         | 18/600 [00:03<01:56,  5.02it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:52365 -> 172.16.1.1:3389, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:   3%|▎         | 19/600 [00:03<01:57,  4.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.3:19092 -> 192.168.1.29:3306, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.3
# Processing packets:   4%|▎         | 22/600 [00:03<01:40,  5.77it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:48183 -> 5.255.96.50:63893, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:   4%|▍         | 24/600 [00:04<01:43,  5.56it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.9:62679 -> 192.168.1.20:8443, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.9
# Processing packets:   4%|▍         | 25/600 [00:04<01:56,  4.92it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.7:60523 -> 185.180.12.15:3389, Score: -0.0491
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.7
# Processing packets:   5%|▍         | 28/600 [00:05<01:36,  5.94it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:45481 -> 192.168.1.11:8443, Score: -0.0172
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:   5%|▍         | 29/600 [00:05<01:47,  5.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:11186 -> 172.16.1.7:21, Score: -0.0374
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:   5%|▌         | 31/600 [00:05<01:38,  5.78it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.39:14343 -> 192.168.1.10:80, Score: -0.0300
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.39
# Processing packets:   6%|▌         | 33/600 [00:05<01:35,  5.97it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:31244 -> 185.174.102.56:445, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.43
# Processing packets:   6%|▌         | 34/600 [00:06<01:35,  5.94it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.32:29663 -> 192.168.1.22:8080, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.32
# Processing packets:   6%|▌         | 36/600 [00:06<01:30,  6.24it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 35.227.248.234:29417 -> 192.168.1.13:8080, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 35.227.248.234
# Processing packets:   6%|▋         | 39/600 [00:07<01:37,  5.76it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 8.8.8.8:29284 -> 192.168.1.26:3389, Score: -0.0345
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 8.8.8.8
# Processing packets:   7%|▋         | 41/600 [00:07<01:28,  6.31it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.24:59325 -> 172.16.1.1:53, Score: -0.0160
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.24
# Processing packets:   7%|▋         | 42/600 [00:07<01:33,  5.98it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:31044 -> 198.51.100.67:25, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:   7%|▋         | 43/600 [00:07<01:33,  5.97it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.25:25785 -> 172.67.169.39:3389, Score: -0.0382
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.25
# Processing packets:   8%|▊         | 50/600 [00:08<01:36,  5.69it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.29:14484 -> 192.168.1.28:25, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.29
# Processing packets:   8%|▊         | 51/600 [00:09<01:31,  5.98it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.35:12979 -> 192.168.1.5:8443, Score: -0.0052
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.35
# Processing packets:   9%|▊         | 52/600 [00:09<01:26,  6.32it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.31:28817 -> 5.255.96.50:22, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.31
# Processing packets:   9%|▉         | 53/600 [00:09<01:25,  6.38it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.4:25966 -> 192.168.1.2:25, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.4
# Processing packets:  10%|▉         | 59/600 [00:10<01:12,  7.50it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.28:11633 -> 140.82.121.4:22, Score: -0.0298
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.28
# Processing packets:  10%|█         | 61/600 [00:10<01:09,  7.80it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.46:62875 -> 172.16.1.6:3389, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.46
# Processing packets:  11%|█         | 67/600 [00:11<01:05,  8.17it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.37:52984 -> 192.168.1.2:21, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.37
# Processing packets:  11%|█▏        | 68/600 [00:11<01:04,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:47110 -> 140.82.121.4:80, Score: -0.0152
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  12%|█▏        | 69/600 [00:11<01:07,  7.84it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:25312 -> 194.36.189.51:445, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:  12%|█▏        | 70/600 [00:11<01:06,  8.01it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.18:60745 -> 194.36.189.51:80, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.18
# Processing packets:  13%|█▎        | 77/600 [00:12<01:01,  8.54it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:29474 -> 192.168.1.22:3306, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  13%|█▎        | 78/600 [00:12<01:03,  8.18it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.48:50408 -> 45.95.147.23:443, Score: -0.0274
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.48
# Processing packets:  14%|█▎        | 82/600 [00:13<01:02,  8.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.40:50747 -> 192.168.1.38:80, Score: -0.0282
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.40
# Processing packets:  14%|█▍        | 84/600 [00:13<01:04,  7.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 1.1.1.1:34017 -> 192.168.1.26:8443, Score: -0.0160
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 1.1.1.1
# Processing packets:  14%|█▍        | 85/600 [00:13<01:03,  8.16it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.7:16556 -> 192.168.1.11:25, Score: -0.0039
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.7
# Processing packets:  14%|█▍        | 87/600 [00:13<01:05,  7.88it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 8.8.8.8:33826 -> 192.168.1.17:445, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 8.8.8.8
# Processing packets:  15%|█▍        | 89/600 [00:13<01:07,  7.62it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.24:53131 -> 5.255.96.50:23, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.24
# Processing packets:  16%|█▌        | 95/600 [00:14<01:01,  8.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.9:57613 -> 192.168.1.33:21, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.9
# Processing packets:  18%|█▊        | 108/600 [00:16<00:59,  8.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.19:33536 -> 198.51.100.67:80, Score: -0.0404
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.19
# Processing packets:  18%|█▊        | 109/600 [00:16<01:00,  8.09it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.1:27318 -> 194.36.189.51:3389, Score: -0.0152
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.1
# Processing packets:  19%|█▉        | 113/600 [00:16<01:00,  8.01it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.37:55285 -> 194.36.189.51:445, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.37
# Processing packets:  19%|█▉        | 116/600 [00:17<00:57,  8.47it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:39269 -> 91.213.8.43:443, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:  20%|█▉        | 117/600 [00:17<00:59,  8.07it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:20578 -> 185.180.12.15:445, Score: -0.0214
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:  20%|█▉        | 118/600 [00:17<00:59,  8.08it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.30:44343 -> 45.95.147.23:443, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.30
# Processing packets:  20%|██        | 121/600 [00:17<01:00,  7.91it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.29:39478 -> 1.1.1.1:22, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.29
# Processing packets:  20%|██        | 122/600 [00:18<00:58,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.14:63565 -> 172.67.169.39:53, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.14
# Processing packets:  21%|██        | 124/600 [00:18<01:01,  7.79it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 140.82.121.4:52341 -> 172.16.1.6:25, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 140.82.121.4
# Processing packets:  22%|██▏       | 132/600 [00:19<00:50,  9.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.27:32856 -> 192.168.1.42:61894, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.27
# Processing packets:  23%|██▎       | 137/600 [00:19<00:50,  9.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.17:53182 -> 104.21.31.84:22, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.17
# Processing packets:  23%|██▎       | 138/600 [00:19<00:53,  8.64it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.23:46428 -> 192.168.1.5:25, Score: -0.0286
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.23
# Processing packets:  24%|██▎       | 141/600 [00:20<00:58,  7.88it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.2:15916 -> 192.168.1.39:80, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.2
# Processing packets:  24%|██▍       | 144/600 [00:20<00:57,  7.92it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.5:34828 -> 65.21.54.1:19342, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.5
# Processing packets:  24%|██▍       | 145/600 [00:20<00:58,  7.72it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:57375 -> 192.168.1.40:8080, Score: -0.0233
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  25%|██▍       | 148/600 [00:21<00:57,  7.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:55244 -> 192.168.1.32:3389, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:  25%|██▌       | 150/600 [00:21<00:52,  8.57it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:53939 -> 91.213.8.43:3389, Score: -0.0163
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:  25%|██▌       | 152/600 [00:21<00:55,  8.12it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:10003 -> 198.51.100.67:8080, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:  26%|██▌       | 156/600 [00:22<00:51,  8.64it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.1:24509 -> 185.174.102.56:3389, Score: -0.0475
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.1
# Processing packets:  26%|██▌       | 157/600 [00:22<00:53,  8.26it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 1.1.1.1:14557 -> 192.168.1.14:8080, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 1.1.1.1
# Processing packets:  27%|██▋       | 162/600 [00:22<00:50,  8.66it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.23:35740 -> 185.174.102.56:3389, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.23
# Processing packets:  27%|██▋       | 164/600 [00:23<00:51,  8.43it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:38907 -> 65.21.54.1:80, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:  28%|██▊       | 169/600 [00:23<00:54,  7.91it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.16:23893 -> 198.51.100.67:443, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.16
# Processing packets:  28%|██▊       | 170/600 [00:23<00:55,  7.72it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.39:59644 -> 192.168.1.38:3389, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.39
# Processing packets:  30%|███       | 183/600 [00:25<00:52,  7.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.31:52374 -> 140.82.121.4:22, Score: -0.0116
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.31
# Processing packets:  31%|███       | 184/600 [00:25<00:51,  8.08it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.12:22900 -> 192.168.1.32:8080, Score: -0.0115
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.12
# Processing packets:  31%|███       | 186/600 [00:25<00:51,  8.08it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:40034 -> 192.168.1.24:23, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:  31%|███▏      | 188/600 [00:26<00:52,  7.83it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.19:12933 -> 172.67.169.39:8080, Score: -0.0059
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.19
# Processing packets:  32%|███▏      | 193/600 [00:26<00:50,  8.10it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.48:22136 -> 104.21.31.84:21, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.48
# Processing packets:  34%|███▎      | 202/600 [00:27<00:48,  8.27it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.25:14725 -> 185.180.12.15:22, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.25
# Processing packets:  35%|███▍      | 209/600 [00:28<00:49,  7.85it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.45:30059 -> 1.1.1.1:23, Score: -0.0540
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.45
# Processing packets:  36%|███▌      | 213/600 [00:29<00:44,  8.67it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.33:30861 -> 192.168.1.3:25, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.33
# Processing packets:  36%|███▋      | 218/600 [00:29<00:46,  8.14it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.40:63219 -> 172.67.169.39:23, Score: -0.0085
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.40
# Processing packets:  37%|███▋      | 223/600 [00:30<00:46,  8.13it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:25150 -> 45.95.147.23:8080, Score: -0.0475
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:  38%|███▊      | 229/600 [00:31<00:50,  7.41it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.34:44214 -> 35.227.248.234:8080, Score: -0.0097
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.34
# Processing packets:  39%|███▉      | 235/600 [00:31<00:48,  7.53it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.20:57261 -> 185.174.102.56:23, Score: -0.0282
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.20
# Processing packets:  40%|███▉      | 239/600 [00:32<00:44,  8.05it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 140.82.121.4:39896 -> 192.168.1.4:8443, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 140.82.121.4
# Processing packets:  43%|████▎     | 258/600 [00:34<00:41,  8.31it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 140.82.121.4:61574 -> 192.168.1.29:8443, Score: -0.0123
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 140.82.121.4
# Processing packets:  44%|████▎     | 262/600 [00:35<00:41,  8.12it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:45601 -> 140.82.121.4:445, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:  44%|████▍     | 266/600 [00:35<00:41,  7.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.17:62467 -> 45.95.147.23:21, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.17
# Processing packets:  46%|████▌     | 275/600 [00:36<00:37,  8.76it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.32:24805 -> 192.168.1.33:23, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.32
# Processing packets:  48%|████▊     | 289/600 [00:38<00:37,  8.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.20:25555 -> 185.180.12.15:25, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.20
# Processing packets:  49%|████▉     | 294/600 [00:39<00:37,  8.19it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:13132 -> 104.21.31.84:3306, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:  51%|█████▏    | 308/600 [00:40<00:34,  8.55it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.45:51342 -> 192.168.1.18:443, Score: -0.0045
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.45
# Processing packets:  52%|█████▏    | 313/600 [00:41<00:34,  8.21it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.38:12821 -> 103.43.141.122:8080, Score: -0.0144
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.38
# Processing packets:  54%|█████▍    | 325/600 [00:42<00:32,  8.41it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.46:43860 -> 192.168.1.41:21, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.46
# Processing packets:  56%|█████▌    | 335/600 [00:44<00:33,  7.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:21166 -> 192.168.1.19:8080, Score: -0.0222
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:  56%|█████▌    | 337/600 [00:44<00:33,  7.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:50739 -> 198.51.100.67:8080, Score: -0.0281
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:  57%|█████▋    | 340/600 [00:44<00:31,  8.18it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:55611 -> 35.227.248.234:80, Score: -0.0475
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  57%|█████▋    | 341/600 [00:44<00:30,  8.36it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:48590 -> 192.168.1.33:3306, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  71%|███████   | 425/600 [00:55<00:21,  8.18it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 104.21.31.84:15191 -> 192.168.1.35:80, Score: -0.0327
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 104.21.31.84
# Processing packets:  74%|███████▎  | 442/600 [00:57<00:19,  7.97it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:47691 -> 35.227.248.234:3389, Score: -0.0193
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.43
# Processing packets:  80%|███████▉  | 479/600 [01:01<00:14,  8.24it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.4:61532 -> 103.43.141.122:443, Score: -0.0075
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.4
# Processing packets:  82%|████████▏ | 493/600 [01:03<00:13,  7.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:10393 -> 185.174.102.56:3389, Score: -0.0191
# WARNING:root:[STEP 4] BLOCKED recurring suspicious activity from 192.168.1.43
# Processing packets:  88%|████████▊ | 527/600 [01:07<00:09,  7.57it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 1.1.1.1:17844 -> 192.168.1.40:28800, Score: -0.0010
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 1.1.1.1
# Processing packets:  90%|█████████ | 541/600 [01:09<00:06,  8.76it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 1.1.1.1:59547 -> 192.168.1.32:3389, Score: -0.0043
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 1.1.1.1
# Processing packets: 100%|██████████| 600/600 [01:17<00:00,  7.79it/s]
# ================================================================================
#                               SIMULATION RESULTS
# ================================================================================
#
# [TRAFFIC STATISTICS]
# Total Packets Processed: 600
# Allowed Packets: 397 (66.17%)
# Blocked Packets: 103 (17.17%)
# Suspicious Packets: 100 (16.67%)
# Unique Source IPs: 74
# Unique Destination IPs: 74
# Total Security Alerts: 101
#
# [TOP 5 TRAFFIC SOURCES]
# 91.213.8.43: 18 packets (3.00%)
# 8.8.8.8: 18 packets (3.00%)
# 1.1.1.1: 18 packets (3.00%)
# 45.95.147.23: 17 packets (2.83%)
# 194.36.189.51: 16 packets (2.67%)
#
# [TOP 5 TRAFFIC DESTINATIONS]
# 194.36.189.51: 22 packets (3.67%)
# 185.180.12.15: 19 packets (3.17%)
# 140.82.121.4: 19 packets (3.17%)
# 172.67.169.39: 16 packets (2.67%)
# 35.227.248.234: 16 packets (2.67%)
#
# [TOP 5 DESTINATION PORTS]
# Port 8443 (HTTPS Alt): 62 packets (10.33%)
# Port 22 (SSH): 53 packets (8.83%)
# Port 443 (HTTPS): 52 packets (8.67%)
# Port 25 (SMTP): 52 packets (8.67%)
# Port 80 (HTTP): 51 packets (8.50%)
#
# [PACKET ACTION DISTRIBUTION]
# ALLOWED: 397 packets (66.17%)
# BLOCKED: 103 packets (17.17%)
# ALLOWED_WITH_WARNING: 100 packets (16.67%)
#
# [ANOMALY SCORE STATISTICS]
# Mean Anomaly Score: 0.0407
# Min Anomaly Score: -0.0540
# Max Anomaly Score: 0.1280
# 25th Percentile: 0.0086
# Median Anomaly Score: 0.0372
# 75th Percentile: 0.0821
#
# ================================================================================
# Visualization files created:
# - firewall_traffic_summary.png - Summary of traffic patterns
# - traffic_over_time.png - Traffic volume over time
# ================================================================================

# %%
def test_ip_addresses(firewall, test_ips, num_packets_per_ip=10):

    results = []

    for ip in test_ips:
        logging.info(f"Testing IP: {ip} with {num_packets_per_ip} packets")
        ip_results = {'src_ip': ip, 'packets': []}

        for _ in range(num_packets_per_ip):

            packet = generate_synthetic_packet()
            packet['src_ip'] = ip


            processed_packet = firewall.process_packet(packet)


            packet_info = {
                'dst_ip': processed_packet['dst_ip'],
                'dst_port': processed_packet['dst_port'],
                'size': processed_packet['size'],
                'final_action': processed_packet['final_action'],
                'anomaly_score': processed_packet.get('anomaly_score', 0),
                'rule_reason': processed_packet.get('rule_reason', ''),
                'context_reason': processed_packet.get('context_reason', '')
            }
            ip_results['packets'].append(packet_info)

        results.append(ip_results)


    print("\n" + "="*80)
    print(" "*30 + "IP TEST RESULTS")
    print("="*80)

    for ip_result in results:
        ip = ip_result['src_ip']
        print(f"\nResults for IP: {ip}")
        print("-"*40)

        action_counts = Counter(p['final_action'] for p in ip_result['packets'])
        for action, count in action_counts.items():
            print(f"{action}: {count} packets ({(count/num_packets_per_ip)*100:.2f}%)")

        avg_anomaly_score = np.mean([p['anomaly_score'] for p in ip_result['packets']])
        print(f"Average Anomaly Score: {avg_anomaly_score:.4f}")

        blocked_packets = [p for p in ip_result['packets'] if p['final_action'] == 'BLOCKED']
        if blocked_packets:
            print("\nBlocked Packets:")
            for p in blocked_packets:
                print(f"  To {p['dst_ip']}:{p['dst_port']} (Size: {p['size']}) - "
                      f"Reason: {p['rule_reason'] or p['context_reason']}")

        suspicious_packets = [p for p in ip_result['packets'] if p['final_action'] == 'ALLOWED_WITH_WARNING']
        if suspicious_packets:
            print("\nSuspicious Packets:")
            for p in suspicious_packets:
                print(f"  To {p['dst_ip']}:{p['dst_port']} (Size: {p['size']}) - "
                      f"Reason: {p['context_reason']}, Anomaly Score: {p['anomaly_score']:.4f}")

    print("\n" + "="*80)

    return results

if __name__ == "__main__":
    firewall = NetworkFirewall()

    test_ips = [
        "203.0.113.45",
        "192.168.1.100",
        "185.174.102.56",
        "172.16.1.5"
    ]

    print("\nRunning initial simulation...")
    firewall, stats, logs_df = run_simulation(duration_seconds=30, packets_per_second=10)

    print("\nTesting specific IP addresses...")
    test_results = test_ip_addresses(firewall, test_ips, num_packets_per_ip=10)
# Out:
# Running initial simulation...
# Processing packets:   0%|          | 0/300 [00:00<?, ?it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.1:36448 -> 35.227.248.234:445, Score: -0.0186
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.1
# Processing packets:   0%|          | 1/300 [00:00<00:42,  6.96it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.6:24509 -> 45.95.147.23:8080, Score: -0.0141
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.6
# Processing packets:   1%|▏         | 4/300 [00:00<00:35,  8.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.17:56950 -> 172.16.1.1:53, Score: -0.0088
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.17
# Processing packets:   2%|▏         | 5/300 [00:00<00:35,  8.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.40:46689 -> 192.168.1.18:8080, Score: -0.0248
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.40
# Processing packets:   2%|▏         | 6/300 [00:00<00:36,  8.02it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.2:53270 -> 91.213.8.43:3389, Score: -0.0151
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.2
# Processing packets:   3%|▎         | 9/300 [00:01<00:32,  8.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.31:42910 -> 192.168.1.23:22, Score: -0.0502
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.31
# Processing packets:   3%|▎         | 10/300 [00:01<00:33,  8.63it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 65.21.54.1:60300 -> 172.16.1.8:8443, Score: -0.0140
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 65.21.54.1
# Processing packets:   4%|▎         | 11/300 [00:01<00:34,  8.41it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 140.82.121.4:34085 -> 192.168.1.14:80, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 140.82.121.4
# Processing packets:   4%|▍         | 12/300 [00:01<00:34,  8.26it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.49:39946 -> 104.21.31.84:53, Score: -0.0498
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.49
# Processing packets:   4%|▍         | 13/300 [00:01<00:35,  8.02it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:26879 -> 1.1.1.1:23, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:   5%|▍         | 14/300 [00:01<00:34,  8.34it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.67.169.39:45237 -> 172.16.1.7:21, Score: -0.0159
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.67.169.39
# Processing packets:   5%|▌         | 15/300 [00:01<00:34,  8.26it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.18:16562 -> 8.8.8.8:25, Score: -0.0494
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.18
# Processing packets:   5%|▌         | 16/300 [00:01<00:33,  8.40it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.47:59095 -> 185.180.12.15:6820, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.47
# Processing packets:   8%|▊         | 24/300 [00:02<00:33,  8.16it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.44:50678 -> 104.21.31.84:3389, Score: -0.0096
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.44
# Processing packets:   9%|▊         | 26/300 [00:03<00:32,  8.53it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.1:45071 -> 192.168.1.20:53525, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.1
# Processing packets:  10%|█         | 31/300 [00:03<00:31,  8.61it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.9:61455 -> 192.168.1.46:80, Score: -0.0502
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.9
# Processing packets:  11%|█         | 32/300 [00:03<00:32,  8.22it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.4:32643 -> 192.168.1.6:3389, Score: -0.0314
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.4
# Processing packets:  11%|█         | 33/300 [00:04<00:32,  8.11it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 198.51.100.67:19189 -> 192.168.1.3:21, Score: -0.0373
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 198.51.100.67
# Processing packets:  11%|█▏        | 34/300 [00:04<00:34,  7.82it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.10:48448 -> 35.227.248.234:80, Score: -0.0494
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.10
# Processing packets:  12%|█▏        | 36/300 [00:04<00:32,  8.14it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 8.8.8.8:39139 -> 192.168.1.8:8443, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 8.8.8.8
# Processing packets:  12%|█▏        | 37/300 [00:04<00:32,  8.10it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.2:22472 -> 91.213.8.43:445, Score: -0.0485
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.2
# Processing packets:  13%|█▎        | 38/300 [00:04<00:33,  7.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.5:55250 -> 192.168.1.33:5432, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.5
# Processing packets:  13%|█▎        | 39/300 [00:04<00:32,  8.13it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.20:64986 -> 192.168.1.1:25, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.20
# Processing packets:  13%|█▎        | 40/300 [00:04<00:32,  7.93it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:28919 -> 192.168.1.46:80, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  14%|█▍        | 42/300 [00:05<00:34,  7.49it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.13:63139 -> 194.36.189.51:3389, Score: -0.0177
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.13
# Processing packets:  15%|█▍        | 44/300 [00:05<00:33,  7.68it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.15:11736 -> 65.21.54.1:21, Score: -0.0373
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.15
# Processing packets:  15%|█▌        | 45/300 [00:05<00:32,  7.83it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.21:46328 -> 35.227.248.234:445, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.21
# Processing packets:  15%|█▌        | 46/300 [00:05<00:31,  8.07it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.5:64162 -> 192.168.1.27:8080, Score: -0.0072
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.5
# Processing packets:  16%|█▌        | 47/300 [00:05<00:32,  7.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 1.1.1.1:46464 -> 192.168.1.48:8443, Score: -0.0088
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 1.1.1.1
# Processing packets:  16%|█▋        | 49/300 [00:06<00:32,  7.72it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.28:30530 -> 45.95.147.23:80, Score: -0.0494
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.28
# Processing packets:  17%|█▋        | 52/300 [00:06<00:31,  7.91it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.19:13201 -> 91.213.8.43:8443, Score: -0.0148
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.19
# Processing packets:  18%|█▊        | 55/300 [00:06<00:29,  8.40it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.42:57995 -> 198.51.100.67:53, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.42
# Processing packets:  19%|█▉        | 57/300 [00:07<00:30,  8.01it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.9:31435 -> 172.67.169.39:3306, Score: -0.0560
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.9
# Processing packets:  20%|██        | 60/300 [00:07<00:27,  8.78it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.29:63111 -> 192.168.1.44:1433, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.29
# Processing packets:  20%|██        | 61/300 [00:07<00:27,  8.54it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.10:51981 -> 198.51.100.67:445, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.10
# Processing packets:  22%|██▏       | 65/300 [00:08<00:29,  8.03it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:11400 -> 172.16.1.6:13115, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  22%|██▏       | 66/300 [00:08<00:29,  7.91it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.4:17956 -> 172.16.1.4:80, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.4
# Processing packets:  22%|██▏       | 67/300 [00:08<00:28,  8.10it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.1:46793 -> 192.168.1.49:22, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.1
# Processing packets:  24%|██▎       | 71/300 [00:08<00:25,  9.07it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.46:28260 -> 203.0.113.45:3306, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.46
# Processing packets:  24%|██▍       | 72/300 [00:08<00:27,  8.33it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.37:58988 -> 192.168.1.14:8080, Score: -0.0163
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.37
# Processing packets:  25%|██▌       | 75/300 [00:09<00:28,  7.89it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.43:51416 -> 65.21.54.1:3306, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.43
# Processing packets:  25%|██▌       | 76/300 [00:09<00:28,  7.73it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:36311 -> 140.82.121.4:23, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  26%|██▌       | 77/300 [00:09<00:28,  7.85it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.22:37571 -> 8.8.8.8:445, Score: -0.0424
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.22
# Processing packets:  27%|██▋       | 80/300 [00:09<00:25,  8.52it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.6:39764 -> 192.168.1.21:443, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.6
# Processing packets:  28%|██▊       | 83/300 [00:10<00:27,  7.88it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 35.227.248.234:17613 -> 192.168.1.32:8443, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 35.227.248.234
# Processing packets:  29%|██▉       | 87/300 [00:10<00:26,  7.91it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.19:50643 -> 8.8.8.8:8080, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.19
# Processing packets:  30%|██▉       | 89/300 [00:10<00:25,  8.28it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.31:11144 -> 192.168.1.40:5432, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.31
# Processing packets:  31%|███       | 93/300 [00:11<00:23,  8.90it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.23:10577 -> 198.51.100.67:25, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.23
# Processing packets:  32%|███▏      | 95/300 [00:11<00:25,  8.12it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.14:28326 -> 192.168.1.21:3306, Score: -0.0369
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.14
# Processing packets:  32%|███▏      | 96/300 [00:11<00:26,  7.77it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.16:50282 -> 1.1.1.1:26361, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.16
# Processing packets:  32%|███▏      | 97/300 [00:11<00:25,  7.95it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.16:56136 -> 185.174.102.56:80, Score: -0.0017
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.16
# Processing packets:  35%|███▌      | 105/300 [00:12<00:23,  8.30it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.4:40960 -> 192.168.1.40:23, Score: -0.0006
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.4
# Processing packets:  36%|███▌      | 107/300 [00:13<00:24,  7.72it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.12:21634 -> 35.227.248.234:80, Score: -0.0424
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.12
# Processing packets:  38%|███▊      | 113/300 [00:13<00:22,  8.24it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.36:21988 -> 45.95.147.23:80, Score: -0.0321
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.36
# Processing packets:  39%|███▊      | 116/300 [00:14<00:22,  8.07it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.26:15881 -> 192.168.1.28:21, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.26
# Processing packets:  40%|███▉      | 119/300 [00:14<00:23,  7.75it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.13:36588 -> 192.168.1.46:3389, Score: -0.0426
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.13
# Processing packets:  41%|████      | 123/300 [00:15<00:21,  8.27it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.13:54205 -> 185.180.12.15:3306, Score: -0.0168
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.13
# Processing packets:  41%|████▏     | 124/300 [00:15<00:21,  8.05it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.38:42354 -> 192.168.1.11:21357, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.38
# Processing packets:  42%|████▏     | 125/300 [00:15<00:22,  7.86it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:36368 -> 8.8.8.8:23, Score: -0.0009
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  42%|████▏     | 127/300 [00:15<00:22,  7.59it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 104.21.31.84:57635 -> 192.168.1.44:53, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 104.21.31.84
# Processing packets:  43%|████▎     | 128/300 [00:15<00:23,  7.24it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 8.8.8.8:63280 -> 192.168.1.6:22, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 8.8.8.8
# Processing packets:  46%|████▌     | 138/300 [00:17<00:19,  8.47it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.24:26111 -> 203.0.113.45:21, Score: -0.0009
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.24
# Processing packets:  48%|████▊     | 145/300 [00:17<00:19,  7.86it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.46:20422 -> 192.168.1.14:3389, Score: -0.0010
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.46
# Processing packets:  49%|████▉     | 148/300 [00:18<00:18,  8.09it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.45:60672 -> 91.213.8.43:25, Score: -0.0141
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.45
# Processing packets:  53%|█████▎    | 158/300 [00:19<00:16,  8.75it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:58512 -> 192.168.1.45:3306, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:  55%|█████▌    | 166/300 [00:20<00:17,  7.78it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.37:56881 -> 203.0.113.45:22, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.37
# Processing packets:  57%|█████▋    | 170/300 [00:20<00:15,  8.16it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 35.227.248.234:21697 -> 192.168.1.49:445, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 35.227.248.234
# Processing packets:  59%|█████▉    | 177/300 [00:21<00:14,  8.49it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.7:35835 -> 192.168.1.29:8080, Score: -0.0064
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.7
# Processing packets:  60%|██████    | 180/300 [00:22<00:15,  7.94it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.48:56403 -> 172.67.169.39:53, Score: -0.0010
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.48
# Processing packets:  62%|██████▏   | 185/300 [00:22<00:14,  7.87it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.25:53411 -> 35.227.248.234:443, Score: -0.0140
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.25
# Processing packets:  64%|██████▍   | 192/300 [00:23<00:14,  7.62it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.39:27422 -> 104.21.31.84:21, Score: -0.0236
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.39
# Processing packets:  65%|██████▌   | 196/300 [00:24<00:13,  7.84it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.19:57255 -> 192.168.1.34:8080, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.19
# Processing packets:  69%|██████▉   | 207/300 [00:25<00:12,  7.61it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.8:14778 -> 192.168.1.21:3306, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.8
# Processing packets:  73%|███████▎  | 220/300 [00:27<00:09,  8.32it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.27:52066 -> 103.43.141.122:21, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.27
# Processing packets:  74%|███████▍  | 223/300 [00:27<00:08,  9.02it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 172.16.1.8:44794 -> 192.168.1.30:8080, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 172.16.1.8
# Processing packets:  79%|███████▉  | 237/300 [00:29<00:08,  7.66it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 104.21.31.84:52101 -> 192.168.1.40:22, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 104.21.31.84
# Processing packets:  81%|████████  | 243/300 [00:30<00:07,  8.02it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.27:38700 -> 192.168.1.43:443, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.27
# Processing packets:  82%|████████▏ | 245/300 [00:30<00:06,  8.00it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:33427 -> 172.16.1.7:53, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:  82%|████████▏ | 246/300 [00:30<00:07,  7.62it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.35:63943 -> 103.43.141.122:23, Score: -0.0591
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.35
# Processing packets:  83%|████████▎ | 250/300 [00:31<00:06,  8.31it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.7:25498 -> 65.21.54.1:21, Score: -0.0141
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.7
# Processing packets:  89%|████████▉ | 268/300 [00:33<00:03,  8.20it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:53926 -> 172.16.1.2:53, Score: -0.0054
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# Processing packets:  91%|█████████ | 273/300 [00:33<00:03,  8.38it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.11:45638 -> 192.168.1.36:53, Score: -0.0180
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.11
# Processing packets:  98%|█████████▊| 294/300 [00:36<00:00,  8.06it/s]WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.7:48336 -> 192.168.1.3:3306, Score: -0.0093
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.7
# Processing packets: 100%|██████████| 300/300 [00:37<00:00,  8.06it/s]
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:42437 -> 192.168.1.23:3389, Score: -0.0063
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:43815 -> 192.168.1.47:53, Score: -0.0026
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:52998 -> 192.168.1.35:22, Score: -0.0038
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 203.0.113.45:44866 -> 192.168.1.48:8443, Score: -0.0038
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 203.0.113.45
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.100:62305 -> 192.168.1.15:8080, Score: -0.0477
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.100
# WARNING:root:[STEP 3] ANOMALOUS packet detected: 192.168.1.100:18806 -> 192.168.1.35:3389, Score: -0.0009
# WARNING:root:[STEP 4] ALLOWED WITH WARNING first-time suspicious from 192.168.1.100
# Testing specific IP addresses...
#
# ================================================================================
#                               IP TEST RESULTS
# ================================================================================
#
# Results for IP: 203.0.113.45
# ----------------------------------------
# ALLOWED_WITH_WARNING: 4 packets (40.00%)
# ALLOWED: 5 packets (50.00%)
# BLOCKED: 1 packets (10.00%)
# Average Anomaly Score: 0.0209
#
# Blocked Packets:
#   To 172.16.1.1:3306 (Size: 437) - Reason: External access to database port 3306
#
# Suspicious Packets:
#   To 192.168.1.23:3389 (Size: 1124) - Reason: First-time suspicious activity, Anomaly Score: -0.0063
#   To 192.168.1.47:53 (Size: 1389) - Reason: First-time suspicious activity, Anomaly Score: -0.0026
#   To 192.168.1.35:22 (Size: 1385) - Reason: First-time suspicious activity, Anomaly Score: -0.0038
#   To 192.168.1.48:8443 (Size: 1397) - Reason: First-time suspicious activity, Anomaly Score: -0.0038
#
# Results for IP: 192.168.1.100
# ----------------------------------------
# ALLOWED_WITH_WARNING: 2 packets (20.00%)
# ALLOWED: 8 packets (80.00%)
# Average Anomaly Score: 0.0386
#
# Suspicious Packets:
#   To 192.168.1.15:8080 (Size: 926) - Reason: First-time suspicious activity, Anomaly Score: -0.0477
#   To 192.168.1.35:3389 (Size: 1416) - Reason: First-time suspicious activity, Anomaly Score: -0.0009
#
# Results for IP: 185.174.102.56
# ----------------------------------------
# BLOCKED: 10 packets (100.00%)
# Average Anomaly Score: 0.0000
#
# Blocked Packets:
#   To 192.168.1.6:8080 (Size: 458) - Reason: Source IP in blocklist
#   To 192.168.1.7:22 (Size: 1032) - Reason: Source IP in blocklist
#   To 192.168.1.25:8443 (Size: 1215) - Reason: Source IP in blocklist
#   To 198.51.100.67:23 (Size: 42750) - Reason: Source IP in blocklist
#   To 203.0.113.45:3306 (Size: 667) - Reason: Source IP in blocklist
#   To 192.168.1.6:21 (Size: 1420) - Reason: Source IP in blocklist
#   To 172.16.1.8:8443 (Size: 215) - Reason: Source IP in blocklist
#   To 8.8.8.8:3306 (Size: 818) - Reason: Source IP in blocklist
#   To 35.227.248.234:53 (Size: 1147) - Reason: Source IP in blocklist
#   To 203.0.113.45:22 (Size: 741) - Reason: Source IP in blocklist
#
# Results for IP: 172.16.1.5
# ----------------------------------------
# ALLOWED: 10 packets (100.00%)
# Average Anomaly Score: 0.0781
#
# ================================================================================

# %%
plt.figure(figsize=(10, 6))
test_df = pd.DataFrame([
    {'src_ip': r['src_ip'], 'anomaly_score': p['anomaly_score']}
    for r in test_results for p in r['packets']
])
sns.boxplot(x='src_ip', y='anomaly_score', data=test_df)
plt.title('Anomaly Scores by Test IP')
plt.xlabel('Source IP')
plt.ylabel('Anomaly Score')
plt.savefig('test_ip_anomaly_scores.png')
plt.close()
